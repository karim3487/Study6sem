# %% [markdown]
# Практическая работа №5 (Проверка статистических гипотез о числовых значениях нормальных распределений)
#
# ЗАДАНИЕ Смоделировать 2 нормальные выборки со следующими параметрами:
#
# <ol>
#     <p>M1(X) = месяц рождения (среднее значение) + 1</p>
#     <p>M2(X) = M1(X) + 1.5</p>
#     <p>D1(X) = номер варианта подгруппы + 1</p>
#     <p>D2(X) = D1(X) + 3</p>
#     <p>Объем первой выборки = 50</p>
#     <p>Объем второй выборки = 100</p>
#
# </ol>
#
# ПРОВЕРИТЬ 6 ГИПОТЕЗ
#
# 1. Гипотеза о числовом значении параметра А (мат. ожидания) при известном параметре сигма^2 (дисперсия)
# 2. Гипотеза о числовом значении параметра А (мат. ожидания) при неизвестном параметре сигма^2 (дисперсия)
# 3. Гипотеза о числовом значении сигма^2 (дисперсии) при неизвестном параметре А (мат. ожидания)
# 4. Гипотеза о равенстве мат. ожиданий 2-х выборок, если обе дисперсии известны
# 5. Гипотеза о равенстве мат. ожиданий 2-х выборок, если обе дисперсии неизвестны, но равны
# 6. Гипотеза о равенстве дисперсий 2-х выборок, если мат. ожидания выборок неизвестны
#
# СДЕЛАТЬ СТАТИСТИЧЕСКИЕ ВЫВОДЫ
#
# АЛГОРИТМ:
#
# 1. Выдвигаем нулевую гипотезу (1 из 6)
# 2. Формулируем альтернативную гипотезу. Например, для гипотезы под №1, когда А = А0 (нулевая гипотеза), альтернативными гипотезами будут А != А0; А > A0; A < A0, где А - мат. ожидание по смоделированной выборке, а А0 задано из условий.
# 3. В зависимости от известных параметров, выбираем статистику критерия, при котором гипотеза принимается или отвергается.
# 4. Строим критическую область с помощью квантилей, которые выбираются по известным параметрам.
# 5. Сделать статистический вывод, при этом если выборочное значение статистики критерия принадлежит области принятия нулевой гипотезы - это гипотеза принимается, иначе рассматривают альтернативные гипотезы.

# %%
import numpy as np
import scipy.stats as ss
from math import sqrt
import matplotlib.pyplot as plt

# %%
def print_result(val, xright, xleft, xright2, xleft2):
    val = np.round(val, 3)
    xright = np.round(xright, 3)
    xleft = np.round(xleft, 3)
    xright2 = np.round(xright2, 3)
    xleft2 = np.round(xleft2, 3)
    print("\tСтатистический вывод:")
    print("\t", end="")
    if xleft < val < xright:
        print(f"Гипотеза принимается на уровне значимости α={alpha}, "
              f"так как выполняется двойное неравенство {xleft} < {val} < {xright}.")
    elif val < xright2:
        print(f"Правосторонний критерий:\n\t{val} < {xright2}")
    else:
        print(f"Левосторонний критерий:\n\t{val} < {xleft2}")

# %%
me_x = (2 + 9) / 2 + 1 # Мат. ожидание 1-ой выборки
me_y = me1 + 1.5 # Мат. ожидание 2-ой выборки
var_x = 7 # Дисперсия 1-ой выборки
var_y = var1 + 3 # Дисперсия 2-ой выборки
n_x = 50 # Объем 1-ой выборки
n_y = 100 # Объем 2-ой выборки
std_x = sqrt(var_x)
std_x = sqrt(var_y)
alpha = 0.1

# %%
# Генерация первой и второй выборок
np.random.seed(0)
sample_x = np.random.normal(me_x, np.sqrt(var_x), n_x)
sample_y = np.random.normal(me_y, np.sqrt(var_y), n_y)
mean_x = np.mean(sample_x)
mean_y = np.mean(sample_y)
a = me_x

# %%
print("1. Гипотеза о числовом значении параметра a при известном параметре σ2.")
U = (mean_x - a) / sqrt(var_x / n_x)
xright = ss.norm.ppf(1 - alpha / 2)
xleft = -xright
xright2 = ss.norm.ppf(1 - alpha)
xleft2 = -xright2
print_result(U, xright, xleft, xright2, xleft2)
# Out:
# 1. Гипотеза о числовом значении параметра a при известном параметре σ2.
# 	Статистический вывод:
# 	Гипотеза принимается на уровне значимости α=0.1, так как выполняется двойное неравенство -1.645 < 0.994 < 1.645.

# %%
print("2. Гипотеза о числовом значении параметра a при неизвестном параметре σ2.")
xvar = np.var(sample_x)
T = (mean_x - a) / sqrt(xvar / n_x)
xright = ss.t.ppf(1 - alpha / 2, n_x - 1)
xleft = -x_right_1
xright2 = ss.t.ppf(1 - alpha, n_x - 1)
xleft2 = -x_right_2
print_result(U, xright, xleft, xright2, xleft2)
# Out:
# 2. Гипотеза о числовом значении параметра a при неизвестном параметре σ2.
# 	Статистический вывод:
# 	Гипотеза принимается на уровне значимости α=0.1, так как выполняется двойное неравенство -1.677 < 0.994 < 1.677.

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %%
print("3. Проверяется гипотеза о числовом значении параметра σ2 при неизвестном параметре a.")
xi = (pow(xvar, 2) * (n_x - 1)) / pow(std_x, 2)
xright = ss.chi2.ppf(1 - ( alpha / 2), n_x - 1)
xleft = ss.chi2.ppf(alpha / 2, n_x - 1)
xright2 = ss.chi2.ppf(1 - alpha, n_x - 1)
xleft2 = ss.chi2.ppf(alpha, n_x - 1)
print_result(xi, xright, xleft, xright2, xleft2)
# Out:
# 3. Проверяется гипотеза о числовом значении параметра σ2 при неизвестном параметре a.
# 	Статистический вывод:
# 	Левосторонний критерий:
# 	385.309 < 36.818

# %%
print("4. Проверяется гипотеза о равенстве математических ожиданий двух выборок, если обе дисперсии выборок известны.")
U2 = (mean_x - mean_y) / sqrt((var_x / n_x) + (var_y / n_x))
xright = ss.norm.ppf(1 - alpha / 2, 0.1)
xleft = -xright
xright2 = ss.norm.ppf(1 - alpha, 0.1)
xleft2 = -xright2
print_result(U, xright, xleft, xright2, xleft2)
# Out:
# 4. Проверяется гипотеза о равенстве математических ожиданий двух выборок, если обе дисперсии выборок известны.
# 	Статистический вывод:
# 	Правосторонний критерий:
# 	-2.574 < 1.382

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-3.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-3.png)

# %%
print("5. Проверяется гипотеза о равенстве математических ожиданий двух выборок, если обе дисперсии выборок неизвестны, но равны между собой.")
yvar = np.var(sample_y)
T2 = (mean_x - mean_y) / (sqrt((1 / n_x + 1 / n_x) * ((n_x - 1) * pow(xvar, 2) + (n_y - 1) * pow(yvar, 2)) / (n_x + n_y - 2)))
xright = ss.t.ppf(1 - alpha / 2, n_x + n_y - 2)
xleft = -xright
xright2 = ss.t.ppf(1 - alpha, n_x + n_y - 2)
xleft2 = -xright2
print_result(T2, xright, xleft, xright2, xleft2)
# Out:
# 5. Проверяется гипотеза о равенстве математических ожиданий двух выборок, если обе дисперсии выборок неизвестны, но равны между собой.
# 	Статистический вывод:
# 	Гипотеза принимается на уровне значимости α=0.1, так как выполняется двойное неравенство -1.655 < -0.821 < 1.655.

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-2.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-2.png)

# %%
print("6. Проверяется гипотеза о равенстве дисперсий двух выборок, при условии, что математические ожидания этих выборок неизвестны.")
up = max(pow(xvar, 2), pow(yvar, 2))
down = min(pow(xvar, 2), pow(yvar, 2))
F = up / down
xright = ss.f.ppf(1 - alpha / 2, n_x - 1, n_y - 1)
xleft = ss.f.ppf(alpha / 2, n_x - 1, n_y - 1)
xright2 = ss.f.ppf(1 - alpha, n_x - 1, n_y - 1)
print_result(F, xright, xleft, xright2, xleft2)
# Out:
# 6. Проверяется гипотеза о равенстве дисперсий двух выборок, при условии, что математические ожидания этих выборок неизвестны.
# 	Статистический вывод:
# 	Гипотеза принимается на уровне значимости α=0.1, так как выполняется двойное неравенство 0.653 < 1.095 < 1.482.
